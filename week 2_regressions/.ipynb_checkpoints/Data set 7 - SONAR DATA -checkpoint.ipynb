# %% [markdown]
# # SONAR DATA SET #

# %% [markdown]
# ## IMPORT MODULES ##

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
import statsmodels.formula.api as sm
import math
from pandas.stats.api import ols
from sklearn.preprocessing import scale
from sklearn.metrics import mean_squared_error
import sklearn.model_selection as m_sel
import plotly.offline as plot
import plotly.graph_objs as go
from sklearn import preprocessing
from sklearn.utils import shuffle
import statsmodels.stats.diagnostic as sms
plot.offline.init_notebook_mode(connected = True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# ## LOAD DATA ##

# %%
sonar = pd.read_csv('Ex07_Sonar_Regreesion.csv')
sonar = shuffle(sonar)
sonar.dropna(axis = 0, inplace = True)

# %% [markdown]
# ## CORRELATION MATRIX ##

# %%
correlation_matrix = sonar.corr()
correlation_matrix
# Out:
#                  EchoTime  WaterTemp  Clconcentration  Salinity        pH  \
# EchoTime         1.000000  -0.033243        -0.057243 -0.057243  0.103163
# WaterTemp       -0.033243   1.000000         0.126242  0.126242 -0.053225
# Clconcentration -0.057243   0.126242         1.000000  1.000000  0.086821
# Salinity        -0.057243   0.126242         1.000000  1.000000  0.086821
# pH               0.103163  -0.053225         0.086821  0.086821  1.000000
# Distance         1.000000  -0.033242        -0.057245 -0.057245  0.103162
#
#                  Distance
# EchoTime         1.000000
# WaterTemp       -0.033242
# Clconcentration -0.057245
# Salinity        -0.057245
# pH               0.103162
# Distance         1.000000

# %% [markdown]
# ## CORRELATION GRAPH ##

# %%
f, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(correlation_matrix, mask=np.zeros_like(correlation_matrix, dtype=np.bool), cmap=sns.diverging_palette(220, 1, as_cmap=True),
            square=True, ax=ax)
plt.show()

# %% [markdown]
# ## SCATTER GRAPH ##

# %%
pd.scatter_matrix(sonar, alpha = .2, figsize = (12, 10), diagonal = 'kde')
plt.show()

# %% [markdown]
# ## NORMALIZING DATA ##

# %%
data_norm = sonar
for i in data_norm.columns.tolist():
    data_norm[i] = (data_norm[i] - data_norm[i].mean()) / (data_norm[i].var())

# %% [markdown]
# ## SPLITTING TRAINING AND TESTING DATA ##

# %%
X_rl = pd.get_dummies(data_norm).drop('Distance', axis = 1)
y_rl = data_norm.Distance
X_train, X_test , Y_train, Y_test = m_sel.train_test_split(X_rl, y_rl, test_size = 0.20, random_state = 20)

# %% [markdown]
# ## LINEAR REGRESSION MODEL ##

# %%
reg = linear_model.LinearRegression(normalize = True)
reg.fit(X_train, Y_train)
print ('Coefficients : ', reg.coef_) 
print ('\nIntercepts  : ', reg.intercept_)
print ('\nRoot Mean Square Error : ', math.sqrt(np.mean((reg.predict(X_test) - Y_test) ** 2)))
# Out:
# Coefficients :  [  1.60000067e-03   3.44821260e-09  -2.37302456e+00   4.28698752e+00
#   -6.49199186e-11]
#
# Intercepts  :  -2.63721646626e-10
#
# Root Mean Square Error :  6.413546623314603e-09

# %% [markdown]
# ## REGRESSION MODEL PLOT ##

# %%
trace1 = go.Scatter(
    x = reg.predict(X_test),
    y = Y_test,
    mode = 'markers',
    name = 'Predicted vs Original',
    line = dict(shape = 'linear')
)
trace2 = go.Scatter(
    x = Y_test,
    y = Y_test,
    mode = 'lines',
    name = 'x = y',
    line = dict(shape = 'linear')
)
data = [trace1, trace2]
layout = dict(
    title = 'SCATTER PLOT FOR REGRESSION MODEL',
    xaxis = dict(
        title = 'PREDICTED VALUE '
    ),
    yaxis = dict(
        title = 'ORIGINAL VALUE'
    ),
    legend = dict(
        traceorder = 'reversed',
        font = dict(size = 16)
    )
)
fig = dict(data = data, layout = layout)
plot.iplot(fig, filename = 'SONAR_Regression Model')
# Out:
# <div id="6e6de16e-d834-4b0f-afc2-f29147c1bed5" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("
}], {}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# ## RIDGE REGRESSION ##

# %%
alphas_ridge = 10 ** np.linspace(-3, 3, 300)

ridge = linear_model.Ridge(normalize = True)
coefs = []
for a in alphas_ridge:
    ridge.set_params(alpha = a)
    ridge.fit(X_train, Y_train)
    coefs.append(ridge.coef_)


coefs = np.array(coefs)
df_ridge = (pd.DataFrame(coefs, columns = X_train.columns, index = alphas_ridge))

# %% [markdown]
# ## WEIGHT VS ALPHA ##

# %%
data = []
for r in range(len(X_train.columns)):
    trace = go.Scatter(
        x = alphas_ridge,
        y = coefs[:, r],
        mode = 'lines+markers',
        name = X_train.columns[r],
        line = dict(shape = 'linear')
    )
    data.append(trace)
layout = dict(
    title = 'WEIGHTS VS ALPHAS',
    yaxis = dict(
        range = [-1, 1],
        title = 'WEIGHT'
    ),
    xaxis = dict(
        range = [0, 0.1],
        title = 'ALPHAS'
    ),
    legend = dict(
        traceorder = 'reversed',
        font = dict(size = 16)
    ))

fig = dict(data = data, layout = layout)
plot.iplot(fig, filename = 'WEIGHT_VS_ALPHA')
# Out:
# <div id="8b0d61f3-e995-4a5d-88d2-1a53b5e0ded6" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8b0d61f3-e995-4a5d-88d2-1a53b5e0ded6", [{"line": {"shape": "linear"}, "x": [0.001, 0.0010472898382363584, 0.001096816005273138, 0.0011486842567375536, 0.0012030053494233243, 0.0012598952777950272, 0.001319475521676706, 0.0013818733056536322, 0.0014472218707411344, 0.0015156607589006028, 0.0015873361110102086, 0.001662400978926612, 0.0017410156523040153, 0.0018233480008684403, 0.0019095738328780967, 0.001999877270535287, 0.0020944511431514688, 0.00219349739890506, 0.0022972275360711512, 0.002405863054644067, 0.0025196359293170162, 0.0026387891048289345, 0.0027635770147361603, 0.0028942661247167516, 0.003031135501567579, 0.0031744774091091933, 0.0033245979322709418, 0.0034818176306889667, 0.0036464722232127486, 0.003818913304781854, 0.003999509097203665, 0.004188645235435271, 0.0043867255910484985, 0.0045941731346364765, 0.0048114308390032594, 0.00503896262506515, 0.0052772543524835375, 0.005526814857144603, 0.005788177037701274, 0.006061898993497572, 0.006348565216305217, 0.006648787838417263, 0.006963207939763883, 0.007292496916841445, 0.007637357916378027, 0.007998527336796709, 0.008376776400682925, 0.008772912801613356, 0.00918778242886334, 0.009622271173675135, 0.010077306820944612, 0.010553861030365236, 0.011052951411260215, 0.011575643695533041, 0.012123054013376522, 0.012696351276599734, 0.013296759674662127, 0.013925561288744634, 0.014584098829439862, 0.01527377850390714, 0.01599607301861488, 0.016752524724082157, 0.017544748908334597, 0.018374437246107267, 0.0192433614111598, 0.02015337685941733, 0.02110642679101555, 0.022104546299710218, 0.02314986671851161, 0.024244620170823284, 0.02539114433680347, 0.026591887445126937, 0.02784941350080644, 0.029166407760237052, 0.030545682465154336, 0.03199018284775065, 0.033502993419772316, 0.03508734455902713, 0.0367466194073669, 0.03848436109487431, 0.04030428030568053, 0.04221026320156901, 0.04420637972028532, 0.046296892266272656, 0.04848626481239081, 0.05077917243205401, 0.053180511282142, 0.055695409058001334, 0.05832923594286206, 0.061087616075050394, 0.0639764395574843, 0.0670018750350959, 0.07017038286703829, 0.07348872892180389, 0.07696399902471159, 0.08060361408861345, 0.08441534596012985, 0.08840733401525062, 0.09258810253973955, 0.0969665789314552, 0.10155211276345681, 0.10635449574860112, 0.11138398264826195, 0.11665131316981961, 0.12216773489967918, 0.12794502732078733, 0.13399552696593384, 0.14033215376054847, 0.1469684386112446, 0.15391855229902054, 0.1611973357388157, 0.16882033167003627, 0.17680381784572086, 0.1851648417912156, 0.1939212572065831, 0.2030917620904737, 0.2126959386668692, 0.22275429519995588, 0.23328830978641582, 0.2443204762186489, 0.25587435201685893, 0.26797460873256923, 0.28064708463098387, 0.29391883986468875, 0.307818214256508, 0.32237488781490303, 0.337619944111134, 0.35358593665351795, 0.3703069584005141, 0.38781871456107236, 0.40615859883769795, 0.4253657732750387, 0.4454812518844989, 0.4665479882234473, 0.48861096711603264, 0.5117173007114605, 0.5359163290848514, 0.5612597255954972, 0.5878016072274912, 0.6155986501483508, 0.644710210732387, 0.6751984523072502, 0.7071284778942997, 0.7405684692262434, 0.7755898323389001, 0.812267350047972, 0.8506793416364162, 0.8909078300934142, 0.933038717262037, 0.9771619672696181, 1.0233717986325201, 1.0717668854455034, 1.122450568085307, 1.17553107387837, 1.2311217482038908, 1.2893412965257156, 1.3503140378698735, 1.414170170289024, 1.4810460488806754, 1.5510844769528405, 1.624435010958867, 1.7012542798525891, 1.7817063195457308, 1.865962923181746, 1.9542040079740535, 2.04661799939199, 2.143402233514857, 2.2447633784132237, 2.3509178754572866, 2.4620924014946257, 2.5785243528842736, 2.700462352420682, 2.8281667802300325, 2. ...

# %% [markdown]
# ## LASSO ##

# %%
alphas_lasso = np.linspace(2, -2, 100) * 0.5 
lasso = linear_model.Lasso(max_iter = 10000, normalize = True)
coefs = []

for a in alphas_lasso:
    lasso.set_params(alpha = a)
    lasso.fit(X_train, Y_train)
    coefs.append(lasso.coef_)


coefs = np.array(coefs)
df_lasso = (pd.DataFrame(coefs, columns = X_train.columns, index = alphas_lasso))

# %% [markdown]
# ## WEIGHT VS ALPHA ##

# %%
data = []
for r in range(len(X_train.columns)):
    trace = go.Scatter(
        x = alphas_lasso,
        y = coefs[:, r],
        mode = 'lines+markers',
        name = X_train.columns[r],
        line = dict(shape = 'linear')
    )
    data.append(trace)
layout = dict(
    title = 'WEIGHTS VS ALPHAS',
    yaxis = dict(
        range = [-3, 3],
        title = 'WEIGHT'
    ),
    xaxis = dict(
        range = [0, 0.1],
        title = 'ALPHAS'
    ),
    legend = dict(
        traceorder = 'reversed',
        font = dict(size = 16)
    ))

fig = dict(data = data, layout = layout)
plot.iplot(fig, filename = 'WEIGHT_VS_ALPHA_SONAR')
# Out:
# <div id="29f5d5e9-a946-455e-a33e-6931933c8141" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot
lassocv.fit(X_train, Y_train)
lasso.set_params(alpha = lassocv.alpha_)
lasso.fit(X_train, Y_train)
mean_squared_error(Y_test, lasso.predict(X_test))
# Out:
# 8.5402904329358603e-13

# %%
pd.Series(lasso.coef_, index = X_test.columns)
# Out:
# EchoTime           0.001598
# WaterTemp          0.000000
# Clconcentration   -0.000000
# Salinity          -0.000000
# pH                 0.000000
# dtype: float64

# %% [markdown]
# ## OLS REGRESSION ##

# %%
ols_result = sm.ols(formula = "Distance ~ EchoTime", data = data_norm.iloc[:math.floor(len(data_norm)*0.70), :]).fit()
ols_result.params
predict_ols = ols_result.predict(X_test)
ols_result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Distance   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 8.600e+11
# Date:                Sun, 02 Apr 2017   Prob (F-statistic):          2.87e-311
# Time:                        19:37:29   Log-Likelihood:                 1085.1
# No. Observations:                  63   AIC:                            -2166.
# Df Residuals:                      61   BIC:                            -2162.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.448e-11   1.04e-09     -0.014      0.989   -2.09e-09    2.06e-09
# EchoTime       0.0016   1.73e-09   9.27e+05      0.000       0.002       0.002
# ==============================================================================
# Omnibus:                        1.976   Durbin-Watson:                   2.087
# Prob(Omnibus):                  0.372   Jarque-Bera (JB):                1.268
# Skew:                          -0.123   Prob(JB):                        0.530
# Kurtosis:                       3.650   Cond. No.                         1.70
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## SCATTER PLOT FOR OLS ##

# %%
trace1 = go.Scatter(
    x = predict_ols,
    y = Y_test,
    mode ='markers',
    name = 'PREDICTED VS ORIGINAL',
    line = dict(shape = 'linear')
)
trace2 = go.Scatter(
    x = Y_test,
    y = Y_test,
    mode = 'lines',
    name = 'x = y',
    line = dict(shape = 'linear')
)
data = [trace1, trace2]
layout = dict(
    title = 'PREDICTED VS ORIGINAL',
    yaxis = dict(
        title = 'PREDICTED VALUE'
    ),
    xaxis = dict(
        title = 'ORIGINAL VALUE'
    ),
    legend = dict(
        traceorder = 'reversed',
        font = dict(size = 16)
    )
)
fig = dict(data = data, layout = layout)
plot.iplot(fig, filename = 'SCATTER PLOT FOR OLS')
# Out:
# <div id="dbd80830-826a-40c4-88d1-dc870ec48b83" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("dbd80830-826a-40c4-88d1-dc870ec48b83", [{"line": {"shape": "linear"}, "x": [0.001629190134324435, 0.00047304338072826747, -0.0010500587786112655, -0.00025994747877043287, 0.001119648093679712, 0.0013239946445301003, 0.0008917314704202778, 0.0008022541536958192, 0.0006946894999817126, 0.0006152668079334571, -0.00026188760775767495, -0.0006289728294853105, -0.000743985449842793, 0.0002868166367180011, 0.0009852029623159096, -0.0010042563087759087, 0.0010622751996053953, 0.0011089628681485687, -0.00024701010223563097], "mode": "markers", "type": "scatter", "name": "PREDICTED VS ORIGINAL", "y": [0.0016291903209730103, 0.00047302848633604605, -0.0010500409791964612, -0.00025994640080979556, 0.0011196389591096219, 0.0013240011997569926, 0.0008917270050441685, 0.0008022592853728613, 0.000694691965884192, 0.0006152660078508724, -0.00026189228431950637, -0.0006289669033838981, -0.0007439840148484805, 0.0002868133967834635, 0.000985207583060777, -0.0010042507256676062, 0.0010622734112860305, 0.0011089685910679098, -0.0002470108563723943]}, {"line": {"shape": "linear"}, "x": [0.0016291903209730103, 0.00047302848633604605, -0.0010500409791964612, -0.00025994640080979556, 0.0011196389591096219, 0.0013240011997569926, 0.0008917270050441685, 0.0008022592853728613, 0.000694691965884192, 0.0006152660078508724, -0.00026189228431950637, -0.0006289669033838981, -0.0007439840148484805, 0.0002868133967834635, 0.000985207583060777, -0.0010042507256676062, 0.0010622734112860305, 0.0011089685910679098, -0.0002470108563723943], "mode": "lines", "type": "scatter", "name": "x = y", "y": [0.0016291903209730103, 0.00047302848633604605, -0.0010500409791964612, -0.00025994640080979556, 0.0011196389591096219, 0.0013240011997569926, 0.0008917270050441685, 0.0008022592853728613, 0.000694691965884192, 0.0006152660078508724, -0.00026189228431950637, -0.0006289669033838981, -0.0007439840148484805, 0.0002868133967834635, 0.000985207583060777, -0.0010042507256676062, 0.0010622734112860305, 0.0011089685910679098, -0.0002470108563723943]}], {"title": "PREDICTED VS ORIGINAL", "xaxis": {"title": "ORIGINAL VALUE"}, "legend": {"traceorder": "reversed", "font": {"size": 16}}, "yaxis": {"title": "PREDICTED VALUE"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# ## HISTOGRAM FOR OLS ##

# %%
data = [go.Histogram(x = ((predict_ols - Y_test)))]
layout = go.Layout(
    title = 'FREQUENCY OF RESIDUALS',
    xaxis = dict(
        title = 'RESIDUALS'
    ),
    yaxis = dict(
        title = 'FREQUENCY'
    )
)
fig = go.Figure(data = data, layout = layout)
plot.iplot(fig, filename = 'OLS_HISTOGRAM_SYSTOLICBP')
# Out:
# <div id="75d973fd-13e1-4d24-aea0-ff6e7cd5dbb2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("75d973fd-13e1-4d24-aea0-ff6e7cd5dbb2", [{"type": "histogram", "x": [-1.866485752847341e-10, 1.4894392221420812e-08, -1.779941480426102e-08, -1.0779606373105197e-09, 9.134570090130537e-09, -6.555226892334884e-09, 4.465376109348031e-09, -5.13167704217863e-09, -2.4659024793882017e-09, 8.000825847112245e-10, 4.676561831415491e-09, -5.926101412432987e-09, -1.434994312504538e-09, 3.2399345376173637e-09, -4.620744867463167e-09, -5.58310830249889e-09, 1.7883193647715706e-09, -5.722919341113325e-09, 7.541367633449522e-10]}], {"title": "FREQUENCY OF RESIDUALS", "yaxis": {"title": "FREQUENCY"}, "xaxis": {"title": "RESIDUALS"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# ## BOX PLOT FOR OLS ##

# %%
trace1 = go.Box(
    y = (predict_ols - Y_test)
)
data = [trace1]
plot.iplot(data)
# Out:
# <div id="e5c4ef65-9e6f-4db7-ac1a-a18bb4feebbc" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e5c4ef65-9e6f-4db7-ac1a-a18bb4feebbc", [{"type": "box", "y": [-1.866485752847341e-10, 1.4894392221420812e-08, -1.779941480426102e-08, -1.0779606373105197e-09, 9.134570090130537e-09, -6.555226892334884e-09, 4.465376109348031e-09, -5.13167704217863e-09, -2.4659024793882017e-09, 8.000825847112245e-10, 4.676561831415491e-09, -5.926101412432987e-09, -1.434994312504538e-09, 3.2399345376173637e-09, -4.620744867463167e-09, -5.58310830249889e-09, 1.7883193647715706e-09, -5.722919341113325e-09, 7.541367633449522e-10]}], {}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# ## Goldfeld Quandt Test ##

# %%
name = ['F statistics', 'p_value']
test = sms.het_goldfeldquandt(ols_result.resid, ols_result.model.exog)
list(zip(name, test))
# Out:
# [('F statistics', 0.51229513907662272), ('p_value', 0.96239893787862385)]
